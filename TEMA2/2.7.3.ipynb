# %%
A(x)=sin(x)-sin(-pi/2-x);
B(x)=pi/2-A(x);
R(x)=A(x)/B(x);
for n in srange (0,90):
    print (n,R(n*pi/180).n());
# Out:
# (0, 1.75193839388411)
# (1, 1.83795309755516)
# (2, 1.92782618982231)
# (3, 2.02174518828884)
# (4, 2.11990430937775)
# (5, 2.22250401952992)
# (6, 2.32975040131253)
# (7, 2.44185429694114)
# (8, 2.55903018589398)
# (9, 2.68149474691118)
# (10, 2.80946504779008)
# (11, 2.94315629913482)
# (12, 3.08277910079914)
# (13, 3.22853610249029)
# (14, 3.38061799333206)
# (15, 3.53919872975018)
# (16, 3.70442990769752)
# (17, 3.87643418510164)
# (18, 4.05529766492596)
# (19, 4.24106116016644)
# (20, 4.43371028160341)
# (21, 4.63316431968223)
# (22, 4.83926393627823)
# (23, 5.05175774320765)
# (24, 5.27028792494701)
# (25, 5.49437516535595)
# (26, 5.72340326339893)
# (27, 5.95660397020911)
# (28, 6.19304274582517)
# (29, 6.43160631123003)
# (30, 6.67099304775158)
# (31, 6.90970745363697)
# (32, 7.14605998298813)
# (33, 7.37817363634740)
# (34, 7.60399861297988)
# (35, 7.82133614076983)
# (36, 8.02787224510202)
# (37, 8.22122169053595)
# (38, 8.39898163631138)
# (39, 8.55879372342090)
# ...

# %% [markdown]
# Sacando las areas con integrales veriamos que el maximo esta alrededor del 45

# %% [markdown]
# El siguiente ejercicio se puede sacar teoricamente.
