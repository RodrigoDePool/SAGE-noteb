# %% [markdown]
# Ejercicio 2

# %%
var('a b')
def f(x):
    if x==1:
        return 1
    if x==2:
        return 1
    else:
        return f(x-2)+f(x-1)

# %%
f(1)
# Out:
# 1

# %%
f(2)
# Out:
# 1

# %%
f(3)
# Out:
# 2

# %%
f(4)
# Out:
# 3

# %%
f(5)
# Out:
# 5

# %%
f(8)
# Out:
# 21

# %%
f(10)
# Out:
# 55

# %%
f(11)
# Out:
# 89

# %%
def g(y):
    return (((1+sqrt(5))/2)^y-((1-sqrt(5))/2)^y)/sqrt(5)

# %%
[f(x)==int(expand(g(x))) for x in srange(1,11)]
# Out:
# [True, True, True, True, True, True, True, True, True, True]

# %% [markdown]
# Las operaciones booleanas solo devolveran TRUE or FALSE si los objetos son del mismo tipo, es importante asegurarse de que son del mismo tipo. Se pueden hacer castings como int()

# %% [markdown]
# Ejercicio 2.7.2

# %%
var('a b')
p(x,a,b)=x**4-6*x**2+a*x+b

# %%
plot(p(x,0,0),(x,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(4*x**3-12*x,(x,-3,3))
# Out:
# Graphics object consisting of 1 graphics primitive
