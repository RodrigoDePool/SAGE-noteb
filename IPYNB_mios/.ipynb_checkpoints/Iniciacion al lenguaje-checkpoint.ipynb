# %% [markdown]
# Esta sera una hoja de pruebas para aprender el lenguaje

# %%
factor(536)
# Out:
# 2^3 * 67

# %%
536.factor()
# Out:
# 2^3 * 67

# %% [markdown]
# Dos formas distintas de usar funciones, forma funcional: funcion(parametros); forma de metodo: (objeto).metodo

# %%
7//4
# Out:
# 1

# %% [markdown]
# Division entera

# %%
def f(x,y):
    return x*y

# %%
f(2,3)
# Out:
# 6

# %%
g(x,y)=x*y

# %%
g(3,2)
# Out:
# 6

# %%
var('a b')
# Out:
# (a, b)

# %%
s=a+b
s1=a*b

# %%
print s; s1
# Out:
# a + b
# a*b

# %%
show([s, s1])
# Out:
# [a + b, a*b]

# %%
a=3;b=2
print s1
# Out:
# a*b

# %%
print s(a=2,b=3)
# Out:
# 5

# %%
ex=s1+3*s
show(ex)
print ex
# Out:
# a*b + 3*a + 3*b
# a*b + 3*a + 3*b

# %%
show(ex.expand())
show(ex.factor())
# Out:
# a*b + 3*a + 3*b
# a*b + 3*a + 3*b

# %%
t=x^2+4*x+4
show(t.expand())
show(t.factor())
# Out:
# x^2 + 4*x + 4
# (x + 2)^2

# %% [markdown]
# Hay formas de simplificar funciones dependiendo del tipo que sean: funcion.simplify (tabulador) nos permite ver un desplegable con las funciones que hay

# %%
f(x)=x^3+x+6
plot(f,(x,-10,10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
point((3,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
point((3,2,1))
# Out:
# Graphics3d Object

# %%
L=[(3,2,1),(4,7,5),(8,2,4)]

# %%
points(L)
# Out:
# Graphics3d Object

# %%
S=[(3,2,0),(0,5,5)]
line(S)
# Out:
# Graphics3d Object

# %%
plot(f,(x,-2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot3d(g,(x,-10,10),(y,-10,10))
# Out:
# Graphics3d Object

# %% [markdown]
# Tambien se pueden dibujar funciones mediante parametrizaciones: parametric plot([f(t),g(t)],(t,0,2)) o parametric plot3d([f(u,v),g(u,v),h(u,v)],(u,0,2),(v,0,2))

# %%
plot(t+f,(x,-2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
print sqrt(2), sqrt(2).n(), n(sqrt(2))
# Out:
# sqrt(2) 1.41421356237310 1.41421356237310

# %%
a=sqrt(2)
b=sqrt(2).n()
print a^2,  b^2
# Out:
# 2 2.00000000000000

# %%
print solve(x+5,x)
print solve(x+5==2,x)
solve([x+y==3,x+3*y==7],x,y)
# Out:
# [
# x == -5
# ]
# [
# x == -3
# ]
# [[x == 1, y == 2]]

# %% [markdown]
# Solve() no siempre consigue soluciones al sistema por lo que podemos utilizar funciones como find_root para encontrar soluciones aproximadas. Si sabemos que las soluciones estan en un intervalo a b, podemos usarlas de la siguiente manera find_root(f,a,b) buscando soluciones a la funcion f(x)=0 en ese intervalo

# %%
sum(1/x^2,x,1,+oo).show()
# Out:
# 1/6*pi^2

# %%
f=1/sin(x)
show(f.integrate(x))
# Out:
# -1/2*log(cos(x) + 1) + 1/2*log(cos(x) - 1)

# %%
f=tan(x)/x
[numerical_integral(f,pi/5,pi/4)]
# Out:
# [(0.19013533541231312, 2.110926271695769e-15)]

# %%
var('m')
l(m)=3**m+(-2)**m
ll=l(m)/l(m+1)
ll.limit(m=oo)
# Out:
# 1/3

# %%
 def f(x): 
    for i in srange (1,n+1):
        adsad
    return

# %%
L=[1,2]
L1=L
L2=list(L)
L2.append(4)
L1.append(3)
L, L1, L2
# Out:
# ([1, 2, 3], [1, 2, 3], [1, 2, 4])

# %% [markdown]
# list crea una lista igual
# mientras si pones solo igual se asigna la misma posicion de memoria

# %%
L=[2,1]
L1=L.sort()
show(L1)
# Out:
# None

# %% [raw]
# Ordena pero no asigna una nueva posicion de memoria, otras funciones como count, index, sum , estan en el pdf de laboratorio. Suma de listas concatena y Producto de listas repite la misma lista n veces

# %%
T=[j+5 for j in srange(1,1000) if j.is_prime()]

# %%
T[0]
# Out:
# 7

# %%
T[-1], T[-2]
# Out:
# (1002, 996)

# %% [markdown]
# ASI SE CUENTA LOS INDICES DE UNA LISTA EMPEZANDO POR EL FINAL (-1 ES ULTIMO -2 PENULTIMO...)

# %%
T[1:3],T[69:]
# Out:
# ([8, 10],
#  [354,
#   358,
#   364,
#   372,
#   378,
#   384,
#   388,
#   394,
#   402,
#   406,
#   414,
#   424,
#   426,
#   436,
#   438,
#   444,
#   448,
#   454,
#   462,
#   466,
#   468,
#   472,
#   484,
#   492,
#   496,
#   504,
#   508,
#   514,
#   526,
#   528,
#   546,
#   552,
#   562,
#   568,
#   574,
#   576,
#   582,
#   592,
#   598,
#   604,
#   606,
#   612,
#   618,
#   622,
#   624,
#   636,
#   646,
#   648,
#   652,
#   658,
#   664,
#   666,
#   678,
#   682,
#   688,
#   696,
#   706,
#   714,
#   724,
#   732,
#   738,
#   744,
#   748,
#   756,
#   762,
#   766,
#   774,
#   778,
#   792,
#   802,
#   814,
#   816,
#   826,
#   828,
#   832,
#   834,
#   844,
#   858,
#   862,
#   864,
#   868,
#   882,
#   886,
#   888,
#   892,
#   912,
#   916,
#   924,
#   934,
#   942,
#   946,
#   952,
#   958,
#   972,
#   976,
#   982,
#   988,
#   996,
#   1002])

# %% [markdown]
# Con esta notacion podemos conseguir sublistas por ejemplo T[A:B] desde A incluido hasta B sin incluir, si no pones B entonces sera hasta el final, si no ponemos A entonces sera desde el principio.
# La notacion T[A:B:c] es la lista con los elementos A, A+c, A+2c, A+3c, ...< B
# L[n]=p cambia el valor del elemento dicho por el valor p  en esa misma posicion
# En las tuplas (a,b,c..) NO se puede modificar el valor de un elemento

# %% [markdown]
# Cadenas de caracteres:
#     str(k) k entero los convierte en una cadena de caracter
#     La operacion + concatena
#     La operacion * repite
#     frabse.index('ab') devuelve el indice a partir del cual la subcadena esta en la cadena frabse
#     ZZ('1234', base=10) convierte a numero una cadena dada

# %%
palabra=['hola','como', 'estas']
'-'.join(palabra)
# Out:
# 'hola-como-estas'

# %%
'/'.join(palabra)
# Out:
# 'hola/como/estas'

# %%
' '.join(palabra)
# Out:
# 'hola como estas'

# %%
C='HOLA COMO ESTAS'
L=C.split(' ')
L
# Out:
# ['HOLA', 'COMO', 'ESTAS']

# %% [markdown]
#  Estructura de datos con Conjuntos VER PDF
#  Estructura de datos con Diccionarios VER PDF
#  VER CLASE  10/10 PARA ENTENDER DICCIONARIO

# %% [raw]
# randint(100,1000) numeros aleatorios entre 100 y 1000

# %% [markdown]
# TECNICAS DE PROGRAMACION:
# ver pdf para las siguientes dudas:
# que es esto?

# %% [markdown]
# Funcion map:
# map(f,L) toma la lista L y a cada elemento le aplica la funcion f y las anade a una lista que luego es devuelta,

# %% [markdown]
# Orbitas:
#     Ver definicion en pdf
#     Cuando se cierran? cuando X es finito.
#     Si X es finito y f biyectivo. X es union disjunta de orbitas cerradas
#
#    Creacion de orbitas finitas (ver funcion en pdf)

# %% [markdown]
# TEMA 5: COMPLEMENTOS
#        %time funcion //mide el tiempo de ejecucion
#     -leer sistemas de numeracion
#     -Trucos de programacion
#         potencias. (base 2)
#         Listas binarias
#         Archivos binarios
#         Enciclopedia de sucesiones de enteros
#         Abrir archivos:
#             open("archivo","w")
#             outfile.write(C)
#             outfile.close()
#         Intersecar listas y conjuntos
#         .
#         .
#         .
#         ver como funciona cProfile
#         compilar en C
#         resto del TEMA5

# %% [markdown]
# Para generar NUMEROS ALEATORIOS tienes que irte a la carpeta del 10-31 y en la hoja de compresion tendras un programa optimo para esto

# %% [markdown]
# Para usar CYTHON y numpy ver las carpetas 10-31 y la anterior. Ademas, vercomo acelerar el codigo con cython y como ver en que partes se tarda mas tiempo en ejecutar el codigo.
# numpy tiene algoritmos de calculo numerico optimizado y otros algoritmos
#
#
# %%cython -a //esta funcion vemos que parte del codigo consume mas tiempo
# import numpy as np //importamos la libreria de numpy
# cimport numpy as np
#
# cimport cython
#
# VER EJEMPLO DE EJECUCION DEL JUEGO DE LA VIDA PARA SABER USAR CYTHON
# cosas como cdef, o np.funcion, o declarar variables

# %% [markdown]
# TEMA 6: TEORIA DE NUMEROS
#  ver fibonacci en pdf
#  ver ejs
#  ejs resueltos en 11-14 FIBO Y OTRAS COSAS

# %% [markdown]
# PRECISION DE CALCULO:
#     expresion.n(digits=d) donde d sera la precision del numero en digitos

# %% [markdown]
# PARTE ENTERA POR ARRIBA: expresion.ceil()
# FIND FIT FUNCTION: VERR. model(x)=a*x+b,find_fit(L3, model)
# Parte entera por abajo floor?
# LEER TEXTO 6.6
